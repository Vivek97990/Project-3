# %% [markdown]
# People Charm’, a growing company is facing a high attrition rate among
# thPeople Charm’, a growing company is facing a high attrition rate among
# their employees which in turn affects their business due to lack of expertise
# and experience.
# • Their HR department is assigned the task to reduce the attrition rate by
# retaining employees who are about to churn out.
# • They need to recommend special plans or strategies which will help them to
# retain their employees which in turn will help them to grow bigger as a
# companyeir employees which in turn affects their business due to lack of expertise
# and experience.
# • Their HR department is assigned the task to reduce the attrition rate by
# retaining employees who are about to churn out.
# • They need to recommend special plans or strategies which will help them to
# retain their employees which in turn will help them to grow bigger as a
# company

# %%
import pandas as pd

# %%
data=pd.read_csv("employees (1).csv")

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
data.shape
# Out:
# (14999, 10)

# %%
#Data prepocessing
#missing values or null values
data.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
data[(data['satisfactoryLevel']==0.46) &(data['lastEvaluation']==0.57)& (data['numberOfProjects']==2) & (data['avgMonthlyHours']==139) & (data['timeSpent.company']==3) & (data['workAccident']==0) & (data['left']==1) & (data['promotionInLast5years']==0) & (data['dept']=='sales') & (data['salary']=='low')]
# Out:
#       satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 17                 0.46            0.57                 2              139
# 263                0.46            0.57                 2              139
# 7984               0.46            0.57                 2              139
# 8228               0.46            0.57                 2              139
# 9472               0.46            0.57                 2              139
# 9733               0.46            0.57                 2              139
#
#       timeSpent.company  workAccident  left  promotionInLast5years   dept  \
# 17                    3             0     1                      0  sales
# 263                   3             0     1                      0  sales
# 7984                  3             0     1                      0  sales
# 8228                  3             0     1                      0  sales
# ...

# %%
#checking for duplicates
data[data.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (11991, 10)

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
data[(data['satisfactoryLevel']==0.46) &(data['lastEvaluation']==0.57)& (data['numberOfProjects']==2) & (data['avgMonthlyHours']==139) & (data['timeSpent.company']==3) & (data['workAccident']==0) & (data['left']==1) & (data['promotionInLast5years']==0) & (data['dept']=='sales') & (data['salary']=='low')]
# Out:
#     satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 17               0.46            0.57                 2              139
#
#     timeSpent.company  workAccident  left  promotionInLast5years   dept salary
# 17                  3             0     1                      0  sales    low

# %%
data.shape
# Out:
# (11991, 10)

# %%
data.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ftr=['dept','numberOfProjects','timeSpent.company','workAccident','promotionInLast5years','salary']

# %%
fig =plt.subplots(figsize=(10,15))
for p,q in enumerate(ftr):
    plt.subplot(3,2,p+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=q,data=data,hue='left')
    plt.xticks(rotation=90)

# %%
print(list(enumerate(ftr)))
# Out:
# [(0, 'dept'), (1, 'numberOfProjects'), (2, 'timeSpent.company'), (3, 'workAccident'), (4, 'promotionInLast5years'), (5, 'salary')]

# %%
list(range(len(ftr)))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
ftr
# Out:
# ['dept',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years',
#  'salary']

# %%
for p,q in enumerate(ftr):
    print(p)
    print(q)
# Out:
# 0
# dept
# 1
# numberOfProjects
# 2
# timeSpent.company
# 3
# workAccident
# 4
# promotionInLast5years
# 5
# salary
